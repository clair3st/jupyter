# %%
import pandas as pd

import numpy as np

# %%
tips = pd.read_csv('./2016-tips.csv')

# %%
tips
# Out:
#     Unnamed: 0       Unnamed: 1  Unnamed: 2 Unnamed: 3    Dad  Unnamed: 5  \
# 0          NaN              NaN         1.0        NaN    NaN         NaN
# 1         24/3         Richmond         NaN    Carlton   Rich         1.0
# 2         26/3        Melbourne         NaN        GWS    GWS         0.0
# 3         26/3       Gold Coast         NaN   Essendon   Gold         1.0
# 4         26/3  North Melbourne         NaN   Adelaide  North         1.0
# ..         ...              ...         ...        ...    ...         ...
# 285        NaN      Grand Final         NaN        NaN    NaN         NaN
# 286        NaN         Bulldogs         NaN     Sydney    Syd         0.0
# 287        NaN              NaN         NaN        NaN      0         NaN
# 288        NaN              NaN         NaN        NaN    NaN         NaN
# 289        NaN      Final total         NaN        NaN    144         NaN
#
#        Mum  Unnamed: 7 Andrew  Unnamed: 9  ...  Peter Unnamed: 13   Erin  \
# ...
